# %%
from PIL import Image
from matplotlib import pyplot as plt

# %%
img = Image.open("/content/testimage.jpg")
small = img.resize((200,300))
plt.imshow(small)

# %%
img.thumbnail((200,300))
plt.imshow(img)

# %%
img.thumbnail((200,300))
plt.imshow(img)
print(img.size)
# Out:
# (200, 151)

# %%
crop = img.crop((0,0,100,150))
plt.imshow(crop)
plt.axis('off')
# Out:
# (-0.5, 99.5, 149.5, -0.5)

# %%
plt.imshow(img)

# %%
img2 = Image.open("/content/HD-wallpaper-surya-handsome-king.jpg")
img2.thumbnail((150,200))
imgcp = img.copy()
imgcp.paste(img2, (50,50))
plt.imshow(imgcp)

# %%
img90 = img2.rotate(90)
plt.imshow(img90)

# %%
flip = img2.transpose(Image.FLIP_LEFT_RIGHT)
plt.imshow(flip)

# %%
grey2 = img2.convert("L")
plt.imshow(grey2, cmap='gray')
