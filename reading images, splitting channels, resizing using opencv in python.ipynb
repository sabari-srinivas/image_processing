# %%
import cv2

img = cv2.imread("/content/rgby1.png",1)
print(img.shape)
# Out:
# (512, 512, 3)

# %%
img = cv2.imread("/content/rgby1.png",0)
print(img.shape)
# Out:
# (512, 512)

# %%
img = cv2.imread("/content/rgby1.png",1)
print(img[0,0])
# Out:
# [ 14   7 159]

# %%
print(img[0,500])
# Out:
# [255  18   3]

# %%
print(img[500,0])
# Out:
# [  7 152 156]

# %%
print(img[500,500])
# Out:
# [ 30 255   3]

# %%
blue = img[:,:,0]
from matplotlib import pyplot as plt
plt.imshow(blue)

# %%
green = img[:,:,1]
plt.imshow(green)

# %%
red = img[:,:,2]
plt.imshow(red)

# %%
b, g, r = cv2.split(img)
mer = cv2.merge((b,g,r))
plt.imshow(mer)
